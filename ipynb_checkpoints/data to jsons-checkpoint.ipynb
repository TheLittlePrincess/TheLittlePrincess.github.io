# %%
import pandas as pd
import json

# %%
df = pd.read_csv("zip_codes.csv")

# %%
df
# Out:
#       ZIP  LOAD_WEIGHT  TOTAL_POPULATION  TOTAL_HOUSEHOLDS  \
# 0   78617      1325600             27900              6520
# 1   78653       825420             20822              6332
# 2   78701       458460              7875              4855
# 3   78702      3741320             22876              8937
# 4   78703      3671428             20788              9723
# 5   78704      5156220             47158             23213
# 6   78705      1606560             33075              8370
# 7   78721      1374760             12447              4197
# 8   78722      1471280              7254              3111
# 9   78723      5984646             33170             12518
# 10  78724      1139940             24833              6360
# 11  78725      2732580              7517              2544
# 12  78726      1595480             14610              5554
# 13  78727      2422020             28999             12937
# 14  78728       711120             21245             10029
# ...

# %%
# Create wellname and date widgets to sort dataframe
zip_list = df['ZIP'].unique().tolist()

# %%
zip_list = df['ZIP']

# %%
zip_list.to_json("zip_code_list.json", orient="values")

# %%
type(jsonString)
# Out:
# str
